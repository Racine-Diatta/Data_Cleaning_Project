# %%
# Importation

# %%
import pandas as pd

# %%
# Importation fichier

# %%
dff = pd.read_csv("CricketTestMatchData_csv.csv",  sep =";")
dff
# Out:
#               Player       Span   Mat  Inns    NO    Runs    HS    Ave     BF  \
# 0   DG Bradman (AUS)  1928-1948  52.0  80.0  10.0  6996.0   334  99.94  9800+
# 1     HC Brook (ENG)  2022-2023  12.0  20.0   1.0  1181.0   186  62.15   1287
# 2     AC Voges (AUS)  2015-2016  20.0  31.0   7.0  1485.0  269*  61.87   2667
# 3    RG Pollock (SA)  1963-1970  23.0  41.0   4.0  2256.0   274  60.97  1707+
# 4    GA Headley (WI)  1930-1954  22.0  40.0   4.0  2190.0  270*  60.83   416+
# ..               ...        ...   ...   ...   ...     ...   ...    ...    ...
# 63   SJ McCabe (AUS)  1930-1938  39.0  62.0   5.0  2748.0   232  48.21  3217+
# 64  DR Jardine (ENG)  1928-1934  22.0  33.0   6.0  1296.0   127  48.00  2110+
# 65               NaN        NaN   NaN   NaN   NaN     NaN   NaN    NaN    NaN
# 66               NaN        NaN   NaN   NaN   NaN     NaN   NaN    NaN    NaN
# 67               NaN              NaN   NaN   NaN     NaN   NaN    NaN    NaN
#
# ...

# %%
# Renommer les colonnes dans une liste
dff.columns

dff=dff.rename(columns={"Span": "playing_span", 
                      "Mat":"matches",
                      "Inns":"innings_bated",
                      "NO":"not_outs",
                      "Runs":"run_scored",
                      "HS":"highest_inns_score",
                      "Ave":"batting_average",
                      "BF":"balls_faced",
                      "SR":"batting_stike_rate",
                      "100":"100s_scored",
                      "50":"50s_scored",
                      "0":"0_ducks_scored",
                      "4s":"boundary_4s",
                      "6s":"boundary_6s"})
dff.head()
# Out:
#              Player playing_span  matches  innings_bated  not_outs  \
# 0  DG Bradman (AUS)    1928-1948     52.0           80.0      10.0
# 1    HC Brook (ENG)    2022-2023     12.0           20.0       1.0
# 2    AC Voges (AUS)    2015-2016     20.0           31.0       7.0
# 3   RG Pollock (SA)    1963-1970     23.0           41.0       4.0
# 4   GA Headley (WI)    1930-1954     22.0           40.0       4.0
#
#    run_scored highest_inns_score  batting_average balls_faced  \
# 0      6996.0                334            99.94       9800+
# 1      1181.0                186            62.15        1287
# 2      1485.0               269*            61.87        2667
# 3      2256.0                274            60.97       1707+
# 4      2190.0               270*            60.83        416+
#
#    batting_stike_rate  100s_scored  50s_scored  0_ducks_scored boundary_4s  \
# 0               58.60         29.0        13.0             7.0        626+
# ...

# %%
dff.columns
# Out:
# Index(['Player', 'playing_span', 'matches', 'innings_bated', 'not_outs',
#        'run_scored', 'highest_inns_score', 'batting_average', 'balls_faced',
#        'batting_stike_rate', '100s_scored', '50s_scored', '0_ducks_scored',
#        'boundary_4s', 'boundary_6s'],
#       dtype='object')

# %%
# Vérification des val. nulles

# %%
dff.isnull().any()
dff.isnull()
# Out:
#     Player  playing_span  matches  innings_bated  not_outs  run_scored  \
# 0    False         False    False          False     False       False
# 1    False         False    False          False     False       False
# 2    False         False    False          False     False       False
# 3    False         False    False          False     False       False
# 4    False         False    False          False     False       False
# ..     ...           ...      ...            ...       ...         ...
# 63   False         False    False          False     False       False
# 64   False         False    False          False     False       False
# 65    True          True     True           True      True        True
# 66    True          True     True           True      True        True
# 67    True         False     True           True      True        True
#
#     highest_inns_score  batting_average  balls_faced  batting_stike_rate  \
# ...

# %%
df = dff.loc[0:64,:]
df
# Out:
#                Player playing_span  matches  innings_bated  not_outs  \
# 0    DG Bradman (AUS)    1928-1948     52.0           80.0      10.0
# 1      HC Brook (ENG)    2022-2023     12.0           20.0       1.0
# 2      AC Voges (AUS)    2015-2016     20.0           31.0       7.0
# 3     RG Pollock (SA)    1963-1970     23.0           41.0       4.0
# 4     GA Headley (WI)    1930-1954     22.0           40.0       4.0
# ..                ...          ...      ...            ...       ...
# 60   KD Walters (AUS)    1965-1981     74.0          125.0      14.0
# 61  GC Smith (ICC/SA)    2002-2014    117.0          205.0      13.0
# 62  WH Ponsford (AUS)    1924-1934     29.0           48.0       4.0
# 63    SJ McCabe (AUS)    1930-1938     39.0           62.0       5.0
# 64   DR Jardine (ENG)    1928-1934     22.0           33.0       6.0
#
#     run_scored highest_inns_score  batting_average balls_faced  \
# 0       6996.0                334            99.94       9800+
# ...

# %%
df.isnull().any()
# Out:
# Player                False
# playing_span          False
# matches               False
# innings_bated         False
# not_outs              False
# run_scored            False
# highest_inns_score    False
# batting_average       False
# balls_faced            True
# batting_stike_rate    False
# 100s_scored           False
# 50s_scored            False
# 0_ducks_scored        False
# boundary_4s           False
# boundary_6s           False
# dtype: bool

# %%
# Nous remarquons que la variable "balls_faced" contient des val. nulle qu'il faudra gérer via ce qui suit

# %%
df[df.balls_faced.isna()==1]
# Rmq: Ce code permet de vérifier si chaque élément de la série est égal à 1. Sahant qu'en Python, 
#      True est équivalent à 1 et False à 0, cela crée une série de booléens où True représente les
#      lignes avec des valeurs manquantes dans la colonne balls_faced.
# Out:
#                   Player playing_span  matches  innings_bated  not_outs  \
# 8         ED Weekes (WI)    1948-1958     48.0           81.0       5.0
# 15       CL Walcott (WI)    1948-1960     44.0           74.0       7.0
# 57  Hon.FS Jackson (ENG)    1893-1905     20.0           33.0       4.0
#
#     run_scored highest_inns_score  batting_average balls_faced  \
# 8       4455.0                207            58.61         NaN
# 15      3798.0                220            56.68         NaN
# 57      1415.0               144*            48.79         NaN
#
#     batting_stike_rate  100s_scored  50s_scored  0_ducks_scored boundary_4s  \
# 8                  0.0         15.0        19.0             6.0        258+
# 15                 0.0         15.0        14.0             1.0        107+
# 57                 0.0          5.0         6.0             3.0         51+
#
#    boundary_6s
# 8            2
# 15          11
# 57           0

# %%
# Imputation par 0
df["balls_faced"]= df.balls_faced.fillna(0)
# Out:
# C:\Users\33788\AppData\Local\Temp\ipykernel_162860\2523875023.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["balls_faced"]= df.balls_faced.fillna(0)

# %%
df
# Out:
#                Player playing_span  matches  innings_bated  not_outs  \
# 0    DG Bradman (AUS)    1928-1948     52.0           80.0      10.0
# 1      HC Brook (ENG)    2022-2023     12.0           20.0       1.0
# 2      AC Voges (AUS)    2015-2016     20.0           31.0       7.0
# 3     RG Pollock (SA)    1963-1970     23.0           41.0       4.0
# 4     GA Headley (WI)    1930-1954     22.0           40.0       4.0
# ..                ...          ...      ...            ...       ...
# 60   KD Walters (AUS)    1965-1981     74.0          125.0      14.0
# 61  GC Smith (ICC/SA)    2002-2014    117.0          205.0      13.0
# 62  WH Ponsford (AUS)    1924-1934     29.0           48.0       4.0
# 63    SJ McCabe (AUS)    1930-1938     39.0           62.0       5.0
# 64   DR Jardine (ENG)    1928-1934     22.0           33.0       6.0
#
#     run_scored highest_inns_score  batting_average balls_faced  \
# 0       6996.0                334            99.94       9800+
# ...

# %%
df[df["Player"]=="CL Walcott (WI)"]
# Out:
#              Player playing_span  matches  innings_bated  not_outs  \
# 15  CL Walcott (WI)    1948-1960     44.0           74.0       7.0
#
#     run_scored highest_inns_score  batting_average balls_faced  \
# 15      3798.0                220            56.68           0
#
#     batting_stike_rate  100s_scored  50s_scored  0_ducks_scored boundary_4s  \
# 15                 0.0         15.0        14.0             1.0        107+
#
#    boundary_6s
# 15          11

# %%
df.isna().sum()
# Out:
# Player                0
# playing_span          0
# matches               0
# innings_bated         0
# not_outs              0
# run_scored            0
# highest_inns_score    0
# batting_average       0
# balls_faced           0
# batting_stike_rate    0
# 100s_scored           0
# 50s_scored            0
# 0_ducks_scored        0
# boundary_4s           0
# boundary_6s           0
# dtype: int64

# %%
# Gestion des doublons

# %%
df.duplicated().sum()
# Nous remarquons la présence de 3 doublons. Ainsi, voyons lesquels avant de les supprimer de la base de données
# Out:
# 3

# %%
df[df["Player"].duplicated()==1]
# Out:
#                Player playing_span  matches  innings_bated  not_outs  \
# 10   WR Hammond (ENG)    1927-1947     85.0          140.0      16.0
# 17     L Hutton (ENG)    1937-1955     79.0          138.0      15.0
# 37  SM Gavaskar (IND)    1971-1987    125.0          214.0      16.0
#
#     run_scored highest_inns_score  batting_average balls_faced  \
# 10      7249.0               336*            58.45       7491+
# 17      6971.0                364            56.67       2844+
# 37     10122.0               236*            51.12      14184+
#
#     batting_stike_rate  100s_scored  50s_scored  0_ducks_scored boundary_4s  \
# 10               38.07         22.0        24.0             4.0        419+
# 17               39.34         19.0        33.0             5.0        358+
# 37               43.35         34.0        45.0            12.0        908+
#
#    boundary_6s
# 10          27
# 17           7
# 37          26

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
### Transformer la colonne "playing_span". On créera 3 nouvelles colonne nommées: "start_carrer", end_carrer, "carrer_length"

# %%
df.columns
# Out:
# Index(['Player', 'playing_span', 'matches', 'innings_bated', 'not_outs',
#        'run_scored', 'highest_inns_score', 'batting_average', 'balls_faced',
#        'batting_stike_rate', '100s_scored', '50s_scored', '0_ducks_scored',
#        'boundary_4s', 'boundary_6s'],
#       dtype='object')

# %%
df.playing_span
# Out:
# 0     1928-1948
# 1     2022-2023
# 2     2015-2016
# 3     1963-1970
# 4     1930-1954
#         ...
# 60    1965-1981
# 61    2002-2014
# 62    1924-1934
# 63    1930-1938
# 64    1928-1934
# Name: playing_span, Length: 62, dtype: object

# %%
df["playing_span"].str.split(pat= '-')
# Out:
# 0     [1928, 1948]
# 1     [2022, 2023]
# 2     [2015, 2016]
# 3     [1963, 1970]
# 4     [1930, 1954]
#           ...
# 60    [1965, 1981]
# 61    [2002, 2014]
# 62    [1924, 1934]
# 63    [1930, 1938]
# 64    [1928, 1934]
# Name: playing_span, Length: 62, dtype: object

# %%
df["playing_span"].str.split(pat= '-').str[0]
# Out:
# 0     1928
# 1     2022
# 2     2015
# 3     1963
# 4     1930
#       ...
# 60    1965
# 61    2002
# 62    1924
# 63    1930
# 64    1928
# Name: playing_span, Length: 62, dtype: object

# %%
df["playing_span"].str.split(pat= '-').str[1]
# Out:
# 0     1948
# 1     2023
# 2     2016
# 3     1970
# 4     1954
#       ...
# 60    1981
# 61    2014
# 62    1934
# 63    1938
# 64    1934
# Name: playing_span, Length: 62, dtype: object

# %%
df["Rookie_year"]= df["playing_span"].str.split(pat= '-').str[0]
# Out:
# C:\Users\33788\AppData\Local\Temp\ipykernel_162860\259028551.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Rookie_year"]= df["playing_span"].str.split(pat= '-').str[0]

# %%
df["Final_year"]= df["playing_span"].str.split(pat= '-').str[1]
# Out:
# C:\Users\33788\AppData\Local\Temp\ipykernel_162860\5624463.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Final_year"]= df["playing_span"].str.split(pat= '-').str[1]

# %%
df
# Out:
#                Player playing_span  matches  innings_bated  not_outs  \
# 0    DG Bradman (AUS)    1928-1948     52.0           80.0      10.0
# 1      HC Brook (ENG)    2022-2023     12.0           20.0       1.0
# 2      AC Voges (AUS)    2015-2016     20.0           31.0       7.0
# 3     RG Pollock (SA)    1963-1970     23.0           41.0       4.0
# 4     GA Headley (WI)    1930-1954     22.0           40.0       4.0
# ..                ...          ...      ...            ...       ...
# 60   KD Walters (AUS)    1965-1981     74.0          125.0      14.0
# 61  GC Smith (ICC/SA)    2002-2014    117.0          205.0      13.0
# 62  WH Ponsford (AUS)    1924-1934     29.0           48.0       4.0
# 63    SJ McCabe (AUS)    1930-1938     39.0           62.0       5.0
# 64   DR Jardine (ENG)    1928-1934     22.0           33.0       6.0
#
#     run_scored highest_inns_score  batting_average balls_faced  \
# 0       6996.0                334            99.94       9800+
# ...

# %%
## Supprimons maintenant la variable "playing_span"
df= df.drop(["playing_span"], axis=1)

# %%
df.head(2)
# Out:
#              Player  matches  innings_bated  not_outs  run_scored  \
# 0  DG Bradman (AUS)     52.0           80.0      10.0      6996.0
# 1    HC Brook (ENG)     12.0           20.0       1.0      1181.0
#
#   highest_inns_score  batting_average balls_faced  batting_stike_rate  \
# 0                334            99.94       9800+               58.60
# 1                186            62.15        1287               91.76
#
#    100s_scored  50s_scored  0_ducks_scored boundary_4s boundary_6s  \
# 0         29.0        13.0             7.0        626+           6
# 1          4.0         7.0             1.0         141          23
#
#   Rookie_year Final_year
# 0        1928       1948
# 1        2022       2023

# %%
## Manipuler la variable "Player" pour en resortir le pays du joueur

# %%
df["Player"].str.split(pat= "(")
# Out:
# 0      [DG Bradman , AUS)]
# 1        [HC Brook , ENG)]
# 2        [AC Voges , AUS)]
# 3       [RG Pollock , SA)]
# 4       [GA Headley , WI)]
#               ...
# 60     [KD Walters , AUS)]
# 61    [GC Smith , ICC/SA)]
# 62    [WH Ponsford , AUS)]
# 63      [SJ McCabe , AUS)]
# 64     [DR Jardine , ENG)]
# Name: Player, Length: 62, dtype: object

# %%
df["Country"]= df["Player"].str.split(pat= "(").str[1]

# %%
df["Country"]
# Out:
# 0        AUS)
# 1        ENG)
# 2        AUS)
# 3         SA)
# 4         WI)
#        ...
# 60       AUS)
# 61    ICC/SA)
# 62       AUS)
# 63       AUS)
# 64       ENG)
# Name: Country, Length: 62, dtype: object

# %%
df["Country"] = df["Country"].str.split(pat= ")").str[0]

# %%
df["Country"]
# Out:
# 0        AUS
# 1        ENG
# 2        AUS
# 3         SA
# 4         WI
#        ...
# 60       AUS
# 61    ICC/SA
# 62       AUS
# 63       AUS
# 64       ENG
# Name: Country, Length: 62, dtype: object

# %%
df["Player"] = df["Player"].str.split(pat= "(").str[0]

# %%
df["Player"]
# Out:
# 0      DG Bradman
# 1        HC Brook
# 2        AC Voges
# 3      RG Pollock
# 4      GA Headley
#           ...
# 60     KD Walters
# 61       GC Smith
# 62    WH Ponsford
# 63      SJ McCabe
# 64     DR Jardine
# Name: Player, Length: 62, dtype: object

# %%
df.head(2)
# Out:
#         Player  matches  innings_bated  not_outs  run_scored  \
# 0  DG Bradman      52.0           80.0      10.0      6996.0
# 1    HC Brook      12.0           20.0       1.0      1181.0
#
#   highest_inns_score  batting_average balls_faced  batting_stike_rate  \
# 0                334            99.94       9800+               58.60
# 1                186            62.15        1287               91.76
#
#    100s_scored  50s_scored  0_ducks_scored boundary_4s boundary_6s  \
# 0         29.0        13.0             7.0        626+           6
# 1          4.0         7.0             1.0         141          23
#
#   Rookie_year Final_year Country
# 0        1928       1948     AUS
# 1        2022       2023     ENG

# %%
### VERIFICATION DES TYPES DE DONNEES
## Nous allons corriger les types de variables une par une

### TAF: Transforme les types de données
#      highest_inns_score ==> INT
#      balls_faced ==> INT
#      boundary_4s ==> INT
#      boundary_6s ==> INT
#      Rookie_year ==> DATE
#      Final_year ==> DATE

# %%
df.dtypes
# Out:
# Player                 object
# matches               float64
# innings_bated         float64
# not_outs              float64
# run_scored            float64
# highest_inns_score     object
# batting_average       float64
# balls_faced            object
# batting_stike_rate    float64
# 100s_scored           float64
# 50s_scored            float64
# 0_ducks_scored        float64
# boundary_4s            object
# boundary_6s            object
# Rookie_year            object
# Final_year             object
# Country                object
# dtype: object

# %%
### La colonne "highest_inns_score" contient des étoile sur certaines valeurs.
#   Il faudra les enlever, puis transformer le types de données

df
# Out:
#           Player  matches  innings_bated  not_outs  run_scored  \
# 0    DG Bradman      52.0           80.0      10.0      6996.0
# 1      HC Brook      12.0           20.0       1.0      1181.0
# 2      AC Voges      20.0           31.0       7.0      1485.0
# 3    RG Pollock      23.0           41.0       4.0      2256.0
# 4    GA Headley      22.0           40.0       4.0      2190.0
# ..           ...      ...            ...       ...         ...
# 60   KD Walters      74.0          125.0      14.0      5357.0
# 61     GC Smith     117.0          205.0      13.0      9265.0
# 62  WH Ponsford      29.0           48.0       4.0      2122.0
# 63    SJ McCabe      39.0           62.0       5.0      2748.0
# 64   DR Jardine      22.0           33.0       6.0      1296.0
#
#    highest_inns_score  batting_average balls_faced  batting_stike_rate  \
# 0                 334            99.94       9800+               58.60
# ...

# %%
df["highest_inns_score"].str.split(pat="*")
# Out:
# 0       [334]
# 1       [186]
# 2     [269, ]
# 3       [274]
# 4     [270, ]
#        ...
# 60      [250]
# 61      [277]
# 62      [266]
# 63      [232]
# 64      [127]
# Name: highest_inns_score, Length: 62, dtype: object

# %%
df["highest_inns_score"] = df["highest_inns_score"].str.split(pat="*").str[0]

# %%
df["highest_inns_score"]
# Out:
# 0     334
# 1     186
# 2     269
# 3     274
# 4     270
#      ...
# 60    250
# 61    277
# 62    266
# 63    232
# 64    127
# Name: highest_inns_score, Length: 62, dtype: object

# %%
df
# Out:
#           Player  matches  innings_bated  not_outs  run_scored  \
# 0    DG Bradman      52.0           80.0      10.0      6996.0
# 1      HC Brook      12.0           20.0       1.0      1181.0
# 2      AC Voges      20.0           31.0       7.0      1485.0
# 3    RG Pollock      23.0           41.0       4.0      2256.0
# 4    GA Headley      22.0           40.0       4.0      2190.0
# ..           ...      ...            ...       ...         ...
# 60   KD Walters      74.0          125.0      14.0      5357.0
# 61     GC Smith     117.0          205.0      13.0      9265.0
# 62  WH Ponsford      29.0           48.0       4.0      2122.0
# 63    SJ McCabe      39.0           62.0       5.0      2748.0
# 64   DR Jardine      22.0           33.0       6.0      1296.0
#
#    highest_inns_score  batting_average balls_faced  batting_stike_rate  \
# 0                 334            99.94       9800+               58.60
# ...

# %%
### Transformer le type de données de "highest_inns_score"
df["highest_inns_score"] = df["highest_inns_score"].astype("int")

# %%
### Transformer le type de données de "Rookie_year" et "Final_year"
df.dtypes
# Out:
# Player                 object
# matches               float64
# innings_bated         float64
# not_outs              float64
# run_scored            float64
# highest_inns_score      int32
# batting_average       float64
# balls_faced            object
# batting_stike_rate    float64
# 100s_scored           float64
# 50s_scored            float64
# 0_ducks_scored        float64
# boundary_4s            object
# boundary_6s            object
# Rookie_year            object
# Final_year             object
# Country                object
# dtype: object

# %%
df= df.astype({"Rookie_year": "int", "Final_year": "int"})

# %%
df.dtypes
# Out:
# Player                 object
# matches               float64
# innings_bated         float64
# not_outs              float64
# run_scored            float64
# highest_inns_score      int32
# batting_average       float64
# balls_faced            object
# batting_stike_rate    float64
# 100s_scored           float64
# 50s_scored            float64
# 0_ducks_scored        float64
# boundary_4s            object
# boundary_6s            object
# Rookie_year             int32
# Final_year              int32
# Country                object
# dtype: object

# %%
df.head()
# Out:
#         Player  matches  innings_bated  not_outs  run_scored  \
# 0  DG Bradman      52.0           80.0      10.0      6996.0
# 1    HC Brook      12.0           20.0       1.0      1181.0
# 2    AC Voges      20.0           31.0       7.0      1485.0
# 3  RG Pollock      23.0           41.0       4.0      2256.0
# 4  GA Headley      22.0           40.0       4.0      2190.0
#
#    highest_inns_score  batting_average balls_faced  batting_stike_rate  \
# 0                 334            99.94       9800+               58.60
# 1                 186            62.15        1287               91.76
# 2                 269            61.87        2667               55.68
# 3                 274            60.97       1707+               54.48
# 4                 270            60.83        416+               56.00
#
#    100s_scored  50s_scored  0_ducks_scored boundary_4s boundary_6s  \
# 0         29.0        13.0             7.0        626+           6
# ...

# %%
### Transformer le type de données de "balls_faced"

# %%
df["balls_faced"] = df["balls_faced"].str.split(pat="+").str[0]

# %%
df[df["balls_faced"].isna()==1]
# Out:
#              Player  matches  innings_bated  not_outs  run_scored  \
# 8        ED Weekes      48.0           81.0       5.0      4455.0
# 15      CL Walcott      44.0           74.0       7.0      3798.0
# 57  Hon.FS Jackson      20.0           33.0       4.0      1415.0
#
#     highest_inns_score  batting_average balls_faced  batting_stike_rate  \
# 8                  207            58.61         NaN                 0.0
# 15                 220            56.68         NaN                 0.0
# 57                 144            48.79         NaN                 0.0
#
#     100s_scored  50s_scored  0_ducks_scored boundary_4s boundary_6s  \
# 8          15.0        19.0             6.0        258+           2
# 15         15.0        14.0             1.0        107+          11
# 57          5.0         6.0             3.0         51+           0
#
#     Rookie_year  Final_year Country
# 8          1948        1958      WI
# 15         1948        1960      WI
# ...

# %%
df.isna().sum()
# Out:
# Player                0
# matches               0
# innings_bated         0
# not_outs              0
# run_scored            0
# highest_inns_score    0
# batting_average       0
# balls_faced           3
# batting_stike_rate    0
# 100s_scored           0
# 50s_scored            0
# 0_ducks_scored        0
# boundary_4s           0
# boundary_6s           0
# Rookie_year           0
# Final_year            0
# Country               0
# dtype: int64

# %%
df["balls_faced"] = df["balls_faced"].fillna(0)

# %%
df["balls_faced"] = df["balls_faced"].astype("int")

# %%
df.dtypes
# Out:
# Player                 object
# matches               float64
# innings_bated         float64
# not_outs              float64
# run_scored            float64
# highest_inns_score      int32
# batting_average       float64
# balls_faced             int32
# batting_stike_rate    float64
# 100s_scored           float64
# 50s_scored            float64
# 0_ducks_scored        float64
# boundary_4s            object
# boundary_6s            object
# Rookie_year             int32
# Final_year              int32
# Country                object
# dtype: object

# %%
df.isna().sum()
# Out:
# Player                0
# matches               0
# innings_bated         0
# not_outs              0
# run_scored            0
# highest_inns_score    0
# batting_average       0
# balls_faced           0
# batting_stike_rate    0
# 100s_scored           0
# 50s_scored            0
# 0_ducks_scored        0
# boundary_4s           0
# boundary_6s           0
# Rookie_year           0
# Final_year            0
# Country               0
# dtype: int64

# %%
pd.set_option('display.max_rows', None)

# %%
df
# Out:
#                Player  matches  innings_bated  not_outs  run_scored  \
# 0         DG Bradman      52.0           80.0      10.0      6996.0
# 1           HC Brook      12.0           20.0       1.0      1181.0
# 2           AC Voges      20.0           31.0       7.0      1485.0
# 3         RG Pollock      23.0           41.0       4.0      2256.0
# 4         GA Headley      22.0           40.0       4.0      2190.0
# 5        H Sutcliffe      54.0           84.0       9.0      4555.0
# 6          E Paynter      20.0           31.0       5.0      1540.0
# 7      KF Barrington      82.0          131.0      15.0      6806.0
# 8          ED Weekes      48.0           81.0       5.0      4455.0
# 9         WR Hammond      85.0          140.0      16.0      7249.0
# 11         GS Sobers      93.0          160.0      21.0      8032.0
# 12     KC Sangakkara     134.0          233.0      17.0     12400.0
# 13         SPD Smith     109.0          195.0      25.0      9685.0
# ...

# %%
### D'abord nous enlévons les "+"  dans les var. boundary_4s" et "boundary_6s"
df["boundary_4s"] = df["boundary_4s"].str.split(pat="+").str[0]
df["boundary_6s"] = df["boundary_6s"].str.split(pat="+").str[0]

# %%
### Transformer le type de données de "boundary_4s" et "boundary_6s". Mais

# %%
# Out:
# Index(['Player', 'matches', 'innings_bated', 'not_outs', 'run_scored',
#        'highest_inns_score', 'batting_average', 'balls_faced',
#        'batting_stike_rate', '100s_scored', '50s_scored', '0_ducks_scored',
#        'boundary_4s', 'boundary_6s', 'Rookie_year', 'Final_year', 'Country'],
#       dtype='object')

# %%
df = df.astype({"boundary_4s":"int","boundary_6s":"int", "matches":"int", "innings_bated":"int",
               "not_outs":"int","run_scored":"int", "100s_scored":"int","50s_scored":"int", "0_ducks_scored":"int"})
df
# Out:
#                Player  matches  innings_bated  not_outs  run_scored  \
# 0         DG Bradman        52             80        10        6996
# 1           HC Brook        12             20         1        1181
# 2           AC Voges        20             31         7        1485
# 3         RG Pollock        23             41         4        2256
# 4         GA Headley        22             40         4        2190
# 5        H Sutcliffe        54             84         9        4555
# 6          E Paynter        20             31         5        1540
# 7      KF Barrington        82            131        15        6806
# 8          ED Weekes        48             81         5        4455
# 9         WR Hammond        85            140        16        7249
# 11         GS Sobers        93            160        21        8032
# 12     KC Sangakkara       134            233        17       12400
# 13         SPD Smith       109            195        25        9685
# ...

# %%
df.dtypes
# Out:
# Player                 object
# matches                 int32
# innings_bated           int32
# not_outs                int32
# run_scored              int32
# highest_inns_score      int32
# batting_average       float64
# balls_faced             int32
# batting_stike_rate    float64
# 100s_scored             int32
# 50s_scored              int32
# 0_ducks_scored          int32
# boundary_4s             int32
# boundary_6s             int32
# Rookie_year             int32
# Final_year              int32
# Country                object
# dtype: object

# %%
## DEFINITION DE LA CARRIERE DES JOUEURS en créant la variable "career_lentgh"

# %%
df["career_lentgh"] = df.Final_year - df.Rookie_year

# %%
df
# Out:
#                Player  matches  innings_bated  not_outs  run_scored  \
# 0         DG Bradman        52             80        10        6996
# 1           HC Brook        12             20         1        1181
# 2           AC Voges        20             31         7        1485
# 3         RG Pollock        23             41         4        2256
# 4         GA Headley        22             40         4        2190
# 5        H Sutcliffe        54             84         9        4555
# 6          E Paynter        20             31         5        1540
# 7      KF Barrington        82            131        15        6806
# 8          ED Weekes        48             81         5        4455
# 9         WR Hammond        85            140        16        7249
# 11         GS Sobers        93            160        21        8032
# 12     KC Sangakkara       134            233        17       12400
# 13         SPD Smith       109            195        25        9685
# ...

# %%
## QUELQUES QUESTIONS
df.columns
# Out:
# Index(['Player', 'matches', 'innings_bated', 'not_outs', 'run_scored',
#        'highest_inns_score', 'batting_average', 'balls_faced',
#        'batting_stike_rate', '100s_scored', '50s_scored', '0_ducks_scored',
#        'boundary_4s', 'boundary_6s', 'Rookie_year', 'Final_year', 'Country',
#        'career_lentgh'],
#       dtype='object')

# %%
### Question 1: Quelles est la carriére moyenne des joueurs de cette Df
df.career_lentgh.mean().round(3)
# Out:
# 13.194

# %%
### Question 2: Déterminer la moy. des taux de frappe en bâton ("batting_stike_rate") des joueurs de plus 10 ans de carriére

df[df.career_lentgh >10]["batting_stike_rate"].mean()

# On arrondit à 2chiffres aprés la virgule
df[df.career_lentgh >10]["batting_stike_rate"].mean().round(2)
# Out:
# 47.95

# %%
### Question 3:  Le nombre de joueurs ayant joué avant 1960
df[df["Rookie_year"] < 1960]["Player"].count()
# Out:
# 23

# %%
### Question 4:  Le max. de highest_inns_score (i.e. score le plus élevé de manches) par pays df[]
df.groupby("Country")["highest_inns_score"].max()
# Out:
# Country
# AUS        380
# ENG        364
# ICC/IND    319
# ICC/PAK    329
# ICC/SA     277
# ICC/WI     400
# IND        254
# NZ         251
# PAK        313
# SA         278
# SL         374
# WI         365
# ZIM        232
# Name: highest_inns_score, dtype: int32

# %%
### pour le mettre sous forma de dataframe
df.groupby("Country")["highest_inns_score"].max().to_frame("Plus_élevé_manches").reset_index().sort_values("Plus_élevé_manches", ascending = False)
# Out:
#     Country  Plus_élevé_manches
# 5    ICC/WI                 400
# 0       AUS                 380
# 10       SL                 374
# 11       WI                 365
# 1       ENG                 364
# 3   ICC/PAK                 329
# 2   ICC/IND                 319
# 8       PAK                 313
# 9        SA                 278
# 4    ICC/SA                 277
# 6       IND                 254
# 7        NZ                 251
# 12      ZIM                 232

# %%
df.columns
# Out:
# Index(['Player', 'matches', 'innings_bated', 'not_outs', 'run_scored',
#        'highest_inns_score', 'batting_average', 'balls_faced',
#        'batting_stike_rate', '100s_scored', '50s_scored', '0_ducks_scored',
#        'boundary_4s', 'boundary_6s', 'Rookie_year', 'Final_year', 'Country',
#        'career_lentgh'],
#       dtype='object')

# %%
### Question 5: 
df.groupby("Country")[['100s_scored', '50s_scored', '0_ducks_scored']].mean().round(3)
# Out:
#          100s_scored  50s_scored  0_ducks_scored
# Country
# AUS           20.625      28.375           8.562
# ENG           12.385      20.846           4.308
# ICC/IND       29.500      47.500          12.000
# ICC/PAK       25.000      46.000          15.000
# ICC/SA        36.000      48.000          13.500
# ICC/WI        34.000      48.000          17.000
# IND           29.500      36.500          10.750
# NZ            18.500      22.000           6.000
# PAK           21.250      28.000           9.500
# SA             9.800      20.200           3.400
# SL            28.667      44.000          12.333
# WI            16.625      25.625           7.250
# ZIM           12.000      27.000           5.000

# %%
### Question 1:
